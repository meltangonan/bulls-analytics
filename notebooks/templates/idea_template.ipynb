# %% [markdown]
# # [Idea Title]\n\nOne-line context for this analysis.

# %% [markdown]
# ## Objective\n\nState the core question in one sentence.

# %% [markdown]
# ## Data Pull

# %%
from bulls import data, analysis, viz\nimport pandas as pd\n\n# Pull only data needed for this idea\ngames = data.get_games(last_n=10)

# %% [markdown]
# ## Analysis

# %%
# Block 1: basic metric\nsummary = {"games": len(games)}\nsummary

# %%
# Block 2: supporting split or trend

# %% [markdown]
# ## Output

# %%
# 1-2 final tables/charts only

# %% [markdown]
# ## Takeaways\n\n- Finding 1\n- Finding 2\n- Finding 3

# %% [markdown]
# ## Next Question\n\nOne line on the next analysis to run.
